# %% [markdown]
# # Proyecto ICM2813
#
# El siguiente proyecto busca que usted pueda implementar un control (del tipo que usted prefiera) de modo de poder controlar un sistema de la vida real.

# %% [markdown]
# # Diseño del controlador.
#
# Como se puede apreciar, el controlador definido a continuación permite a partir de la señal medida del sensor de línea controlar el robot para mantener la referencia alineada con el centro de la pista. El diseño del controlador es libre y puede utilizar el método que más prefiera. Ejemplos de controladores que puede implementar son : PID, Banga-Bang, Control óptimo, Control Robusto, control no lineal, control predictivo, control difuso, Redes Neuronales y un largo etc.

# %%
from ICM2813.Server import LineFollower

class MiControlador:

    def __init__(self):
        # Variables de ejemplo
        self.var = 2
        self.foo = True
        
        #Variable sugerida (se puede modificar)
        self.base_speed = 1

    def calculate(self, error, dt):
        '''
        Esta función es la única que se requiere para poder correr el programa. Si lo desea puede agregar más  
        funciones a la clase controlador (__init__). Esta función recibe como entrada (ya calculada) lo siguiente:
        * error: Que corresponde a la distancia al centro de la línea cuando estamos sobre ella (varía entre -3500 y 3500)
        * dt: diferencia de tiempo entre cada vez que se le actualizan los comandos al robot (50 ms)
        A continuación se presenta un código para mover el robot en línea recta independiente del error.
        '''
        
        # Definir velocidad de giro del robot
        velang = 0

        # Mapenado las señales de vel lineal y ángular del robot a la vel de cada rueda
        w_derecha   = self.base_speed + velang
        w_izquierda = self.base_speed - velang
        return (w_derecha, w_izquierda)


controlador = MiControlador()
LF = LineFollower(controlador)
LF.run()
del(LF)
# Out:
#   Running B0 Remote API client with channel name [b0RemoteApi]
#   make sure that: 1) the B0 resolver is running
#                   2) CoppeliaSim is running the B0 Remote API server with the same channel name
#   Initializing...
#
#
#   Connected!
#
# Inicializando seguidor de linea
# counts : 1
# Estoy calculando cosas !
# counts : 2
# Estoy calculando cosas !
# counts : 3
# Estoy calculando cosas !
# counts : 4
# Estoy calculando cosas !
# counts : 5
# Estoy calculando cosas !
# counts : 6
# Estoy calculando cosas !
# counts : 7
# Estoy calculando cosas !
# counts : 8
# Estoy calculando cosas !
# counts : 9
# Estoy calculando cosas !
# counts : 10
# Estoy calculando cosas !
# counts : 11
# Estoy calculando cosas !
# counts : 12
# Estoy calculando cosas !
# counts : 13
# Estoy calculando cosas !
# counts : 14
# Estoy calculando cosas !
# counts : 15
# Estoy calculando cosas !
# counts : 16
# Estoy calculando cosas !
# counts : 17
# Estoy calculando cosas !
# counts : 18
# Estoy calculando cosas !
# counts : 19
# Estoy calculando cosas !
# counts : 20
# Estoy calculando cosas !
# counts : 21
# Estoy calculando cosas !
# counts : 22
# Estoy calculando cosas !
# counts : 23
# Estoy calculando cosas !
# counts : 24
# Estoy calculando cosas !
# counts : 25
# Estoy calculando cosas !
# counts : 26
# Estoy calculando cosas !
# counts : 27
# Estoy calculando cosas !
# counts : 28
# Estoy calculando cosas !
# counts : 29
# Estoy calculando cosas !
# counts : 30
# Estoy calculando cosas !
# counts : 31
# Estoy calculando cosas !
# counts : 32
# Estoy calculando cosas !
# counts : 33
# Estoy calculando cosas !
# counts : 34
# Estoy calculando cosas !
# counts : 35
# Estoy calculando cosas !
# counts : 36
# Estoy calculando cosas !
# counts : 37
# Estoy calculando cosas !
# counts : 38
# Estoy calculando cosas !
# counts : 39
# Estoy calculando cosas !
# counts : 40
# Estoy calculando cosas !
# counts : 41
# Estoy calculando cosas !
# counts : 42
# Estoy calculando cosas !
# counts : 43
# Estoy calculando cosas !
# counts : 44
# Estoy calculando cosas !
# counts : 45
# Estoy calculando cosas !
# counts : 46
# Estoy calculando cosas !
# counts : 47
# Estoy calculando cosas !
# counts : 48
# Estoy calculando cosas !
# counts : 49
# Estoy calculando cosas !
# counts : 50
# Estoy calculando cosas !
# counts : 51
# Estoy calculando cosas !
# counts : 52
# Estoy calculando cosas !
# counts : 53
# Estoy calculando cosas !
# counts : 54
# Estoy calculando cosas !
# counts : 55
# Estoy calculando cosas !
# counts : 56
# Estoy calculando cosas !
# counts : 57
# Estoy calculando cosas !
# counts : 58
# Estoy calculando cosas !
# counts : 59
# Estoy calculando cosas !
# counts : 60
# Estoy calculando cosas !
# counts : 61
# Estoy calculando cosas !
# counts : 62
# Estoy calculando cosas !
# counts : 63
# Estoy calculando cosas !
# counts : 64
# Estoy calculando cosas !
# counts : 65
# Estoy calculando cosas !
# counts : 66
# Estoy calculando cosas !
# counts : 67
# Estoy calculando cosas !
# counts : 68
# Estoy calculando cosas !
# counts : 69
# Estoy calculando cosas !
# counts : 70
# Estoy calculando cosas !
# counts : 71
# Estoy calculando cosas !
# counts : 72
# Estoy calculando cosas !
# counts : 73
# Estoy calculando cosas !
# counts : 74
# Estoy calculando cosas !
# counts : 75
# Estoy calculando cosas !
# counts : 76
# Estoy calculando cosas !
# counts : 77
# Estoy calculando cosas !
# counts : 78
# Estoy calculando cosas !
# counts : 79
# Estoy calculando cosas !
# counts : 80
# Estoy calculando cosas !
# counts : 81
# Estoy calculando cosas !
# counts : 82
# Estoy calculando cosas !
# counts : 83
# Estoy calculando cosas !
# counts : 84
# Estoy calculando cosas !
# counts : 85
# Estoy calculando cosas !
# counts : 86
# Estoy calculando cosas !
# counts : 87
# Estoy calculando cosas !
# counts : 88
# Estoy calculando cosas !
# counts : 89
# Estoy calculando cosas !
# counts : 90
# Estoy calculando cosas !
# counts : 91
# Estoy calculando cosas !
# counts : 92
# Estoy calculando cosas !
# counts : 93
# Estoy calculando cosas !
# counts : 94
# Estoy calculando cosas !
# counts : 95
# Estoy calculando cosas !
# counts : 96
# Estoy calculando cosas !
# counts : 97
# Estoy calculando cosas !
# counts : 98
# Estoy calculando cosas !
# counts : 99
# Estoy calculando cosas !
# counts : 100
# Estoy calculando cosas !
# counts : 101
# Estoy calculando cosas !
# counts : 102
# Estoy calculando cosas !
# counts : 103
# Estoy calculando cosas !
# counts : 104
# Estoy calculando cosas !
# counts : 105
# Estoy calculando cosas !
# counts : 106
# Estoy calculando cosas !
# counts : 107
# Estoy calculando cosas !
# counts : 108
# Estoy calculando cosas !
# counts : 109
# Estoy calculando cosas !
# counts : 110
# Estoy calculando cosas !
# counts : 111
# Estoy calculando cosas !
# counts : 112
# Estoy calculando cosas !
# counts : 113
# Estoy calculando cosas !
# counts : 114
# Estoy calculando cosas !
# counts : 115
# Estoy calculando cosas !
# counts : 116
# Estoy calculando cosas !
# counts : 117
# Estoy calculando cosas !
# counts : 118
# Estoy calculando cosas !
# counts : 119
# Estoy calculando cosas !
# counts : 120
# Estoy calculando cosas !
# counts : 121
# Estoy calculando cosas !
# counts : 122
# Estoy calculando cosas !
# counts : 123
# Estoy calculando cosas !
# counts : 124
# Estoy calculando cosas !
# counts : 125
# Estoy calculando cosas !
# counts : 126
# Estoy calculando cosas !
# counts : 127
# Estoy calculando cosas !
# counts : 128
# Estoy calculando cosas !
# counts : 129
# Estoy calculando cosas !
# counts : 130
# Estoy calculando cosas !
# counts : 131
# Estoy calculando cosas !
# counts : 132
# Estoy calculando cosas !
# counts : 133
# Estoy calculando cosas !
# counts : 134
# Estoy calculando cosas !
# counts : 135
# Estoy calculando cosas !
# counts : 136
# Estoy calculando cosas !
# counts : 137
# Estoy calculando cosas !
# counts : 138
# Estoy calculando cosas !
# counts : 139
# Estoy calculando cosas !
# counts : 140
# Estoy calculando cosas !
# counts : 141
# Estoy calculando cosas !
# counts : 142
# Estoy calculando cosas !
# counts : 143
# Estoy calculando cosas !
# counts : 144
# Estoy calculando cosas !
# counts : 145
# Estoy calculando cosas !
# counts : 146
# Estoy calculando cosas !
# counts : 147
# Estoy calculando cosas !
# counts : 148
# Estoy calculando cosas !
# counts : 149
# Estoy calculando cosas !
# counts : 150
# Estoy calculando cosas !
# counts : 151
# Estoy calculando cosas !
# counts : 152
# Estoy calculando cosas !
# counts : 153
# Estoy calculando cosas !
# counts : 154
# Estoy calculando cosas !
# counts : 155
# Estoy calculando cosas !
# counts : 156
# Estoy calculando cosas !
# counts : 157
# Estoy calculando cosas !
# counts : 158
# Estoy calculando cosas !
# counts : 159
# Estoy calculando cosas !
# counts : 160
# Estoy calculando cosas !
# counts : 161
# Estoy calculando cosas !
# counts : 162
# Estoy calculando cosas !
# counts : 163
# Estoy calculando cosas !
# counts : 164
# Estoy calculando cosas !
# counts : 165
# Estoy calculando cosas !
# counts : 166
# Estoy calculando cosas !
# counts : 167
# Estoy calculando cosas !
# counts : 168
# Estoy calculando cosas !
# counts : 169
# Estoy calculando cosas !
# counts : 170
# Estoy calculando cosas !
# counts : 171
# Estoy calculando cosas !
# counts : 172
# Estoy calculando cosas !
# counts : 173
# Estoy calculando cosas !
# counts : 174
# Estoy calculando cosas !
# counts : 175
# Estoy calculando cosas !
# counts : 176
# Estoy calculando cosas !
# counts : 177
# Estoy calculando cosas !
# counts : 178
# Estoy calculando cosas !
# counts : 179
# Estoy calculando cosas !
# counts : 180
# Estoy calculando cosas !
# counts : 181
# Estoy calculando cosas !
# counts : 182
# Estoy calculando cosas !
# counts : 183
# Estoy calculando cosas !
# counts : 184
# Estoy calculando cosas !
# counts : 185
# Estoy calculando cosas !
# counts : 186
# Estoy calculando cosas !
# counts : 187
# Estoy calculando cosas !
# counts : 188
# Estoy calculando cosas !
# counts : 189
# Estoy calculando cosas !
# counts : 190
# Estoy calculando cosas !
# counts : 191
# Estoy calculando cosas !
# counts : 192
# Estoy calculando cosas !
# counts : 193
# Estoy calculando cosas !
# counts : 194
# Estoy calculando cosas !
# counts : 195
# Estoy calculando cosas !
# counts : 196
# Estoy calculando cosas !
# counts : 197
# Estoy calculando cosas !
# counts : 198
# Estoy calculando cosas !
# counts : 199
# Estoy calculando cosas !
# counts : 200
# Estoy calculando cosas !
# counts : 201
# Estoy calculando cosas !
# counts : 202
# Estoy calculando cosas !
# counts : 203
# Estoy calculando cosas !
# counts : 204
# Estoy calculando cosas !
# counts : 205
# Estoy calculando cosas !
# counts : 206
# Estoy calculando cosas !
# counts : 207
# Estoy calculando cosas !
# counts : 208
# Estoy calculando cosas !
# counts : 209
# Estoy calculando cosas !
# counts : 210
# Estoy calculando cosas !
# counts : 211
# Estoy calculando cosas !
# counts : 212
# Estoy calculando cosas !
# counts : 213
# Estoy calculando cosas !
# counts : 214
# Estoy calculando cosas !
# counts : 215
# Estoy calculando cosas !
# counts : 216
# Estoy calculando cosas !
# counts : 217
# Estoy calculando cosas !
# counts : 218
# Estoy calculando cosas !
# counts : 219
# Estoy calculando cosas !
# counts : 220
# Estoy calculando cosas !
# counts : 221
# Estoy calculando cosas !
# counts : 222
# Estoy calculando cosas !
# counts : 223
# Estoy calculando cosas !
# counts : 224
# Estoy calculando cosas !
# counts : 225
# Estoy calculando cosas !
# counts : 226
# Estoy calculando cosas !
# counts : 227
# Estoy calculando cosas !
# counts : 228
# Estoy calculando cosas !
# counts : 229
# Estoy calculando cosas !
# counts : 230
# Estoy calculando cosas !
# counts : 231
# Estoy calculando cosas !
# counts : 232
# Estoy calculando cosas !
# counts : 233
# Estoy calculando cosas !
# counts : 234
# Estoy calculando cosas !
# counts : 235
# Estoy calculando cosas !
# counts : 236
# Estoy calculando cosas !
# counts : 237
# Estoy calculando cosas !
# counts : 238
# Estoy calculando cosas !
# counts : 239
# Estoy calculando cosas !
# counts : 240
# Estoy calculando cosas !
# counts : 241
# Estoy calculando cosas !
# counts : 242
# Estoy calculando cosas !
# counts : 243
# Estoy calculando cosas !
# counts : 244
# Estoy calculando cosas !
# counts : 245
# Estoy calculando cosas !
# counts : 246
# Estoy calculando cosas !
# counts : 247
# Estoy calculando cosas !
# counts : 248
# Estoy calculando cosas !
# counts : 249
# Estoy calculando cosas !
# counts : 250
# Estoy calculando cosas !
# counts : 251
# Estoy calculando cosas !
# counts : 252
# Estoy calculando cosas !
# counts : 253
# Estoy calculando cosas !
# counts : 254
# Estoy calculando cosas !
# counts : 255
# Estoy calculando cosas !
# counts : 256
# Estoy calculando cosas !
# counts : 257
# Estoy calculando cosas !
# counts : 258
# Estoy calculando cosas !
# counts : 259
# Estoy calculando cosas !
# counts : 260
# Estoy calculando cosas !
# counts : 261
# Estoy calculando cosas !
# counts : 262
# Estoy calculando cosas !
# counts : 263
# Estoy calculando cosas !
# counts : 264
# Estoy calculando cosas !
# counts : 265
# Estoy calculando cosas !
# counts : 266
# Estoy calculando cosas !
# counts : 267
# Estoy calculando cosas !
# counts : 268
# Estoy calculando cosas !
# counts : 269
# Estoy calculando cosas !
# counts : 270
# Estoy calculando cosas !
# counts : 271
# Estoy calculando cosas !
# counts : 272
# Estoy calculando cosas !
# counts : 273
# Estoy calculando cosas !
# counts : 274
# Estoy calculando cosas !
# counts : 275
# Estoy calculando cosas !
# counts : 276
# Estoy calculando cosas !
# counts : 277
# Estoy calculando cosas !
# counts : 278
# Estoy calculando cosas !
# counts : 279
# Estoy calculando cosas !
# counts : 280
# Estoy calculando cosas !
# counts : 281
# Estoy calculando cosas !
# counts : 282
# Estoy calculando cosas !
# counts : 283
# Estoy calculando cosas !
# counts : 284
# Estoy calculando cosas !
# counts : 285
# Estoy calculando cosas !
# counts : 286
# Estoy calculando cosas !
# counts : 287
# Estoy calculando cosas !
# counts : 288
# Estoy calculando cosas !
# counts : 289
# Estoy calculando cosas !
# counts : 290
# Estoy calculando cosas !
# counts : 291
# Estoy calculando cosas !
# counts : 292
# Estoy calculando cosas !
# counts : 293
# Estoy calculando cosas !
# counts : 294
# Estoy calculando cosas !
# counts : 295
# Estoy calculando cosas !
# counts : 296
# Estoy calculando cosas !
# counts : 297
# Estoy calculando cosas !
# counts : 298
# Estoy calculando cosas !
# counts : 299
# Estoy calculando cosas !
# counts : 300
# Estoy calculando cosas !
# counts : 301
# Estoy calculando cosas !
# counts : 302
# Estoy calculando cosas !
# counts : 303
# Estoy calculando cosas !
# counts : 304
# Estoy calculando cosas !
# counts : 305
# Estoy calculando cosas !
# counts : 306
# Estoy calculando cosas !
# counts : 307
# Estoy calculando cosas !
# counts : 308
# Estoy calculando cosas !
# counts : 309
# Estoy calculando cosas !
# counts : 310
# Estoy calculando cosas !
# counts : 311
# Estoy calculando cosas !
# counts : 312
# Estoy calculando cosas !
# counts : 313
# Estoy calculando cosas !
# counts : 314
# Estoy calculando cosas !
# counts : 315
# Estoy calculando cosas !
# counts : 316
# Estoy calculando cosas !
# counts : 317
# Estoy calculando cosas !
# counts : 318
# Estoy calculando cosas !
# counts : 319
# Estoy calculando cosas !
# counts : 320
# Estoy calculando cosas !
# counts : 321
# Estoy calculando cosas !
# counts : 322
# Estoy calculando cosas !
# counts : 323
# Estoy calculando cosas !
# counts : 324
# Estoy calculando cosas !
# counts : 325
# Estoy calculando cosas !
# counts : 326
# Estoy calculando cosas !
# counts : 327
# Estoy calculando cosas !
# counts : 328
# Estoy calculando cosas !
# counts : 329
# Estoy calculando cosas !
# counts : 330
# Estoy calculando cosas !
# counts : 331
# Estoy calculando cosas !
# counts : 332
# Estoy calculando cosas !
# counts : 333
# Estoy calculando cosas !
# counts : 334
# Estoy calculando cosas !
# counts : 335
# Estoy calculando cosas !
# counts : 336
# Estoy calculando cosas !
# counts : 337
# Estoy calculando cosas !
# counts : 338
# Estoy calculando cosas !
# counts : 339
# Estoy calculando cosas !
# counts : 340
# Estoy calculando cosas !
# counts : 341
# Estoy calculando cosas !
# counts : 342
# Estoy calculando cosas !
# counts : 343
# Estoy calculando cosas !
# counts : 344
# Estoy calculando cosas !
# counts : 345
# Estoy calculando cosas !
# counts : 346
# Estoy calculando cosas !
# counts : 347
# Estoy calculando cosas !
# counts : 348
# Estoy calculando cosas !
# counts : 349
# Estoy calculando cosas !
# counts : 350
# Estoy calculando cosas !
# counts : 351
# Estoy calculando cosas !
# counts : 352
# Estoy calculando cosas !
# counts : 353
# Estoy calculando cosas !
# counts : 354
# Estoy calculando cosas !
# counts : 355
# Estoy calculando cosas !
# counts : 356
# Estoy calculando cosas !
# counts : 357
# Estoy calculando cosas !
# counts : 358
# Estoy calculando cosas !
# counts : 359
# Estoy calculando cosas !
# counts : 360
# Estoy calculando cosas !
# counts : 361
# Estoy calculando cosas !
# counts : 362
# Estoy calculando cosas !
# counts : 363
# Estoy calculando cosas !
# counts : 364
# Estoy calculando cosas !
# counts : 365
# Estoy calculando cosas !
# counts : 366
# Estoy calculando cosas !
# counts : 367
# Estoy calculando cosas !
# counts : 368
# Estoy calculando cosas !
# counts : 369
# Estoy calculando cosas !
# counts : 370
# Estoy calculando cosas !
# counts : 371
# Estoy calculando cosas !
# counts : 372
# Estoy calculando cosas !
# counts : 373
# Estoy calculando cosas !
# counts : 374
# Estoy calculando cosas !
# counts : 375
# Estoy calculando cosas !
# counts : 376
# Estoy calculando cosas !
# counts : 377
# Estoy calculando cosas !
# counts : 378
# Estoy calculando cosas !
# counts : 379
# Estoy calculando cosas !
# counts : 380
# Estoy calculando cosas !
# counts : 381
# Estoy calculando cosas !
# counts : 382
# Estoy calculando cosas !
# counts : 383
# Estoy calculando cosas !
# counts : 384
# Estoy calculando cosas !
# counts : 385
# Estoy calculando cosas !
# counts : 386
# Estoy calculando cosas !
# counts : 387
# Estoy calculando cosas !
# counts : 388
# Estoy calculando cosas !
# counts : 389
# Estoy calculando cosas !
# counts : 390
# Estoy calculando cosas !
# counts : 391
# Estoy calculando cosas !
# counts : 392
# Estoy calculando cosas !
# counts : 393
# Estoy calculando cosas !
# counts : 394
# Estoy calculando cosas !
# counts : 395
# Estoy calculando cosas !
# counts : 396
# Estoy calculando cosas !
# counts : 397
# Estoy calculando cosas !
# counts : 398
# Estoy calculando cosas !
# counts : 399
# Estoy calculando cosas !
# counts : 400
# Estoy calculando cosas !
# counts : 401
# Estoy calculando cosas !
# counts : 402
# Estoy calculando cosas !
# counts : 403
# Estoy calculando cosas !
# counts : 404
# Estoy calculando cosas !
# counts : 405
# Estoy calculando cosas !
# counts : 406
# Estoy calculando cosas !
# counts : 407
# Estoy calculando cosas !
# counts : 408
# Estoy calculando cosas !
# counts : 409
# Estoy calculando cosas !
# counts : 410
# Estoy calculando cosas !
# counts : 411
# Estoy calculando cosas !
# counts : 412
# Estoy calculando cosas !
# counts : 413
# Estoy calculando cosas !
# counts : 414
# Estoy calculando cosas !
# counts : 415
# Estoy calculando cosas !
# counts : 416
# Estoy calculando cosas !
# counts : 417
# Estoy calculando cosas !
# counts : 418
# Estoy calculando cosas !
# counts : 419
# Estoy calculando cosas !
# counts : 420
# Estoy calculando cosas !
# counts : 421
# Estoy calculando cosas !
# counts : 422
# Estoy calculando cosas !
# counts : 423
# Estoy calculando cosas !
# counts : 424
# Estoy calculando cosas !
# counts : 425
# Estoy calculando cosas !
# counts : 426
# Estoy calculando cosas !
# counts : 427
# Estoy calculando cosas !
# counts : 428
# Estoy calculando cosas !
# counts : 429
# Estoy calculando cosas !
# counts : 430
# Estoy calculando cosas !
# counts : 431
# Estoy calculando cosas !
# counts : 432
# Estoy calculando cosas !
# counts : 433
# Estoy calculando cosas !
# counts : 434
# Estoy calculando cosas !
# counts : 435
# Estoy calculando cosas !
# counts : 436
# Estoy calculando cosas !
# counts : 437
# Estoy calculando cosas !
# counts : 438
# Estoy calculando cosas !
# counts : 439
# Estoy calculando cosas !
# counts : 440
# Estoy calculando cosas !
# counts : 441
# Estoy calculando cosas !
# counts : 442
# Estoy calculando cosas !
# counts : 443
# Estoy calculando cosas !
# counts : 444
# Estoy calculando cosas !
# counts : 445
# Estoy calculando cosas !
# counts : 446
# Estoy calculando cosas !
# counts : 447
# Estoy calculando cosas !
# counts : 448
# Estoy calculando cosas !
# counts : 449
# Estoy calculando cosas !
# counts : 450
# Estoy calculando cosas !
# counts : 451
# Estoy calculando cosas !
# counts : 452
# Estoy calculando cosas !
# counts : 453
# Estoy calculando cosas !
# counts : 454
# Estoy calculando cosas !
# counts : 455
# Estoy calculando cosas !
# counts : 456
# Estoy calculando cosas !
# counts : 457
# Estoy calculando cosas !
# counts : 458
# Estoy calculando cosas !
# counts : 459
# Estoy calculando cosas !
# counts : 460
# Estoy calculando cosas !
# counts : 461
# Estoy calculando cosas !
# counts : 462
# Estoy calculando cosas !
# counts : 463
# Estoy calculando cosas !
# counts : 464
# Estoy calculando cosas !
# counts : 465
# Estoy calculando cosas !
# counts : 466
# Estoy calculando cosas !
# counts : 467
# Estoy calculando cosas !
# counts : 468
# Estoy calculando cosas !
# counts : 469
# Estoy calculando cosas !
# counts : 470
# Estoy calculando cosas !
# counts : 471
# Estoy calculando cosas !
# counts : 472
# Estoy calculando cosas !
# counts : 473
# Estoy calculando cosas !
# counts : 474
# Estoy calculando cosas !
# counts : 475
# Estoy calculando cosas !
# counts : 476
# Estoy calculando cosas !
# counts : 477
# Estoy calculando cosas !
# counts : 478
# Estoy calculando cosas !
# counts : 479
# Estoy calculando cosas !
# counts : 480
# Estoy calculando cosas !
# counts : 481
# Estoy calculando cosas !
# counts : 482
# Estoy calculando cosas !
# counts : 483
# Estoy calculando cosas !
# counts : 484
# Estoy calculando cosas !
# counts : 485
# Estoy calculando cosas !
# counts : 486
# Estoy calculando cosas !
# counts : 487
# Estoy calculando cosas !
# counts : 488
# Estoy calculando cosas !
# counts : 489
# Estoy calculando cosas !
# counts : 490
# Estoy calculando cosas !
# counts : 491
# Estoy calculando cosas !
# counts : 492
# Estoy calculando cosas !
# counts : 493
# Estoy calculando cosas !
# counts : 494
# Estoy calculando cosas !
# counts : 495
# Estoy calculando cosas !
# counts : 496
# Estoy calculando cosas !
# counts : 497
# Estoy calculando cosas !
# counts : 498
# Estoy calculando cosas !
# counts : 499
# Estoy calculando cosas !
# counts : 500
# Estoy calculando cosas !
# counts : 501
# Estoy calculando cosas !
# counts : 502
# Estoy calculando cosas !
# counts : 503
# Estoy calculando cosas !
# counts : 504
# Estoy calculando cosas !
# counts : 505
# Estoy calculando cosas !
# counts : 506
# Estoy calculando cosas !
# counts : 507
# Estoy calculando cosas !
# counts : 508
# Estoy calculando cosas !
# counts : 509
# Estoy calculando cosas !
# counts : 510
# Estoy calculando cosas !
# counts : 511
# Estoy calculando cosas !
# counts : 512
# Estoy calculando cosas !
# counts : 513
# Estoy calculando cosas !
# counts : 514
# Estoy calculando cosas !
# counts : 515
# Estoy calculando cosas !
# counts : 516
# Estoy calculando cosas !
# counts : 517
# Estoy calculando cosas !
# counts : 518
# Estoy calculando cosas !
# counts : 519
# Estoy calculando cosas !
# counts : 520
# Estoy calculando cosas !
# counts : 521
# Estoy calculando cosas !
# counts : 522
# Estoy calculando cosas !
# counts : 523
# Estoy calculando cosas !
# counts : 524
# Estoy calculando cosas !
# counts : 525
# Estoy calculando cosas !
# counts : 526
# Estoy calculando cosas !
# counts : 527
# Estoy calculando cosas !
# counts : 528
# Estoy calculando cosas !
# counts : 529
# Estoy calculando cosas !
# counts : 530
# Estoy calculando cosas !
# counts : 531
# Estoy calculando cosas !
# counts : 532
# Estoy calculando cosas !
# counts : 533
# Estoy calculando cosas !
# counts : 534
# Estoy calculando cosas !
# counts : 535
# Estoy calculando cosas !
# counts : 536
# Estoy calculando cosas !
# counts : 537
# Estoy calculando cosas !
# counts : 538
# Estoy calculando cosas !
# counts : 539
# Estoy calculando cosas !
# counts : 540
# Estoy calculando cosas !
# counts : 541
# Estoy calculando cosas !
# counts : 542
# Estoy calculando cosas !
# counts : 543
# Estoy calculando cosas !
# counts : 544
# Estoy calculando cosas !
# counts : 545
# Estoy calculando cosas !
# counts : 546
# Estoy calculando cosas !
# counts : 547
# Estoy calculando cosas !
# counts : 548
# Estoy calculando cosas !
# counts : 549
# Estoy calculando cosas !
# counts : 550
# Estoy calculando cosas !
# counts : 551
# Estoy calculando cosas !
# counts : 552
# Estoy calculando cosas !
# counts : 553
# Estoy calculando cosas !
# counts : 554
# Estoy calculando cosas !
# counts : 555
# Estoy calculando cosas !
# counts : 556
# Estoy calculando cosas !
# counts : 557
# Estoy calculando cosas !
# counts : 558
# Estoy calculando cosas !
# counts : 559
# Estoy calculando cosas !
# counts : 560
# Estoy calculando cosas !
# counts : 561
# Estoy calculando cosas !
# counts : 562
# Estoy calculando cosas !
# counts : 563
# Estoy calculando cosas !
# counts : 564
# Estoy calculando cosas !
# counts : 565
# Estoy calculando cosas !
# counts : 566
# Estoy calculando cosas !
# counts : 567
# Estoy calculando cosas !
# counts : 568
# Estoy calculando cosas !
# counts : 569
# Estoy calculando cosas !
# counts : 570
# Estoy calculando cosas !
# counts : 571
# Estoy calculando cosas !
# counts : 572
# Estoy calculando cosas !
# counts : 573
# Estoy calculando cosas !
# counts : 574
# Estoy calculando cosas !
# counts : 575
# Estoy calculando cosas !
# counts : 576
# Estoy calculando cosas !
# counts : 577
# Estoy calculando cosas !
# counts : 578
# Estoy calculando cosas !
# counts : 579
# Estoy calculando cosas !
# counts : 580
# Estoy calculando cosas !
# counts : 581
# Estoy calculando cosas !
# counts : 582
# Estoy calculando cosas !
# counts : 583
# Estoy calculando cosas !
# counts : 584
# Estoy calculando cosas !
# counts : 585
# Estoy calculando cosas !
# counts : 586
# Estoy calculando cosas !
# counts : 587
# Estoy calculando cosas !
# counts : 588
# Estoy calculando cosas !
# counts : 589
# Estoy calculando cosas !
# counts : 590
# Estoy calculando cosas !
# counts : 591
# Estoy calculando cosas !
# counts : 592
# Estoy calculando cosas !
# counts : 593
# Estoy calculando cosas !
# counts : 594
# counts : 595
# counts : 596
# counts : 597
# counts : 598
# counts : 599
# counts : 600
# counts : 601
# counts : 602
# counts : 603
# counts : 604
# counts : 605
# counts : 606
# counts : 607
# counts : 608
# counts : 609
# counts : 610
# counts : 611
# counts : 612
# counts : 613
# counts : 614
# counts : 615
# counts : 616
# counts : 617
# counts : 618
# counts : 619
# counts : 620
# counts : 621
# counts : 622
# counts : 623
# counts : 624
# counts : 625
# counts : 626
# counts : 627
# counts : 628
# counts : 629
# counts : 630
# counts : 631
# counts : 632
# counts : 633
# counts : 634
# counts : 635
# counts : 636
# counts : 637
# counts : 638
# counts : 639
# counts : 640
# counts : 641
# counts : 642
# counts : 643
# counts : 644
# counts : 645
# counts : 646
# counts : 647
# counts : 648
# counts : 649
# counts : 650
# counts : 651
# counts : 652
# counts : 653
# counts : 654
# counts : 655
# counts : 656
# counts : 657
# counts : 658
# counts : 659
# counts : 660
# counts : 661
# counts : 662
# counts : 663
# counts : 664
# counts : 665
# counts : 666
# counts : 667
# counts : 668
# counts : 669
# counts : 670
# counts : 671
# counts : 672
# counts : 673
# counts : 674
# counts : 675
# counts : 676
# counts : 677
# counts : 678
# counts : 679
# counts : 680
# counts : 681
# counts : 682
# counts : 683
# counts : 684
# counts : 685
# counts : 686
# counts : 687
# counts : 688
# counts : 689
# counts : 690
# counts : 691
# counts : 692
# counts : 693
# counts : 694
# counts : 695
# counts : 696
# counts : 697
# counts : 698
# counts : 699
# counts : 700
# counts : 701
# counts : 702
# counts : 703
# counts : 704
# counts : 705
# counts : 706
# counts : 707
# counts : 708
# counts : 709
# counts : 710
# counts : 711
# counts : 712
# counts : 713
# counts : 714
# counts : 715
# counts : 716
# counts : 717
# counts : 718
# counts : 719
# counts : 720
# counts : 721
# counts : 722
# counts : 723
# counts : 724
# counts : 725
# counts : 726
# counts : 727
# counts : 728
# counts : 729
# counts : 730
# counts : 731
# counts : 732
# counts : 733
# counts : 734
# counts : 735
# counts : 736
# counts : 737
# counts : 738
# counts : 739
# counts : 740
# counts : 741
# counts : 742
# counts : 743
# counts : 744
# counts : 745
# counts : 746
# counts : 747
# counts : 748
# counts : 749
# counts : 750
# counts : 751
# counts : 752
# counts : 753
# counts : 754
# counts : 755
# counts : 756
# counts : 757
# counts : 758
# counts : 759
# counts : 760
# counts : 761
# counts : 762
# counts : 763
# counts : 764
# counts : 765
# counts : 766
# counts : 767
# counts : 768
# counts : 769
# counts : 770
# counts : 771
# counts : 772
# counts : 773
# counts : 774
# counts : 775
# counts : 776
# counts : 777
# counts : 778
# counts : 779
# counts : 780
# counts : 781
# counts : 782
# counts : 783
# counts : 784
# counts : 785
# counts : 786
# counts : 787
# counts : 788
# counts : 789
# counts : 790
# counts : 791
# counts : 792
# counts : 793
# counts : 794
# counts : 795
# counts : 796
# counts : 797
# counts : 798
# counts : 799
# counts : 800
# counts : 801
# counts : 802
# counts : 803
# counts : 804
# counts : 805
# counts : 806
# counts : 807
# counts : 808
# Estoy calculando cosas !
# counts : 809
# Estoy calculando cosas !
# counts : 810
# Estoy calculando cosas !
# counts : 811
# Estoy calculando cosas !
# counts : 812
# Estoy calculando cosas !
# counts : 813
# Estoy calculando cosas !
# counts : 814
# Estoy calculando cosas !
# counts : 815
# Estoy calculando cosas !
# counts : 816
# Estoy calculando cosas !
# counts : 817
# Estoy calculando cosas !
# counts : 818
# Estoy calculando cosas !
# counts : 819
# Estoy calculando cosas !
# counts : 820
# Estoy calculando cosas !
# counts : 821
# Estoy calculando cosas !
# counts : 822
# Estoy calculando cosas !
# counts : 823
# Estoy calculando cosas !
# counts : 824
# Estoy calculando cosas !
# counts : 825
# Estoy calculando cosas !
# counts : 826
# Estoy calculando cosas !
# counts : 827
# Estoy calculando cosas !
# counts : 828
# Estoy calculando cosas !
# counts : 829
# Estoy calculando cosas !
# counts : 830
# Estoy calculando cosas !
# counts : 831
# Estoy calculando cosas !
# counts : 832
# Estoy calculando cosas !
# counts : 833
# Estoy calculando cosas !
# counts : 834
# Estoy calculando cosas !
# counts : 835
# Estoy calculando cosas !
# counts : 836
# Estoy calculando cosas !
# counts : 837
# Estoy calculando cosas !
# counts : 838
# Estoy calculando cosas !
# counts : 839
# Estoy calculando cosas !
# counts : 840
# Estoy calculando cosas !
# counts : 841
# Estoy calculando cosas !
# counts : 842
# Estoy calculando cosas !
# counts : 843
# Estoy calculando cosas !
# counts : 844
# Estoy calculando cosas !
# counts : 845
# Estoy calculando cosas !
# counts : 846
# Estoy calculando cosas !
# counts : 847
# Estoy calculando cosas !
# counts : 848
# Estoy calculando cosas !
# counts : 849
# Estoy calculando cosas !
# counts : 850
# Estoy calculando cosas !
# counts : 851
# Estoy calculando cosas !
# counts : 852
# Estoy calculando cosas !
# counts : 853
# Estoy calculando cosas !
# counts : 854
# Estoy calculando cosas !
# counts : 855
# Estoy calculando cosas !
# counts : 856
# Estoy calculando cosas !
# counts : 857
# Estoy calculando cosas !
# counts : 858
# Estoy calculando cosas !
# counts : 859
# Estoy calculando cosas !
# counts : 860
# Estoy calculando cosas !
# counts : 861
# Estoy calculando cosas !
# counts : 862
# Estoy calculando cosas !
# counts : 863
# Estoy calculando cosas !
# counts : 864
# Estoy calculando cosas !
# counts : 865
# Estoy calculando cosas !
# counts : 866
# Estoy calculando cosas !
# counts : 867
# Estoy calculando cosas !
# counts : 868
# Estoy calculando cosas !
# counts : 869
# Estoy calculando cosas !
# counts : 870
# Estoy calculando cosas !
# counts : 871
# Estoy calculando cosas !
# counts : 872
# Estoy calculando cosas !
# counts : 873
# Estoy calculando cosas !
# counts : 874
# Estoy calculando cosas !
# counts : 875
# Estoy calculando cosas !
# counts : 876
# Estoy calculando cosas !
# counts : 877
# Estoy calculando cosas !
# counts : 878
# Estoy calculando cosas !
# counts : 879
# Estoy calculando cosas !
# counts : 880
# Estoy calculando cosas !
# counts : 881
# Estoy calculando cosas !
# counts : 882
# Estoy calculando cosas !
# counts : 883
# Estoy calculando cosas !
# counts : 884
# Estoy calculando cosas !
# counts : 885
# Estoy calculando cosas !
# counts : 886
# Estoy calculando cosas !
# counts : 887
# Estoy calculando cosas !
# counts : 888
# Estoy calculando cosas !
# counts : 889
# Estoy calculando cosas !
# counts : 890
# Estoy calculando cosas !
# counts : 891
# Estoy calculando cosas !
# counts : 892
# Estoy calculando cosas !
# counts : 893
# Estoy calculando cosas !
# counts : 894
# Estoy calculando cosas !
# counts : 895
# Estoy calculando cosas !
# counts : 896
# Estoy calculando cosas !
# counts : 897
# Estoy calculando cosas !
# counts : 898
# Estoy calculando cosas !
# counts : 899
# Estoy calculando cosas !
# counts : 900
# Estoy calculando cosas !
# counts : 901
# Estoy calculando cosas !
# counts : 902
# Estoy calculando cosas !
# counts : 903
# Estoy calculando cosas !
# counts : 904
# Estoy calculando cosas !
# counts : 905
# Estoy calculando cosas !
# counts : 906
# Estoy calculando cosas !
# counts : 907
# Estoy calculando cosas !
# counts : 908
# Estoy calculando cosas !
# counts : 909
# Estoy calculando cosas !
# counts : 910
# Estoy calculando cosas !
# counts : 911
# Estoy calculando cosas !
# counts : 912
# Estoy calculando cosas !
# counts : 913
# Estoy calculando cosas !
# counts : 914
# Estoy calculando cosas !
# counts : 915
# Estoy calculando cosas !
# counts : 916
# Estoy calculando cosas !
# counts : 917
# Estoy calculando cosas !
# counts : 918
# Estoy calculando cosas !
# counts : 919
# Estoy calculando cosas !
# counts : 920
# Estoy calculando cosas !
# counts : 921
# Estoy calculando cosas !
# counts : 922
# Estoy calculando cosas !
# counts : 923
# Estoy calculando cosas !
# counts : 924
# Estoy calculando cosas !
# counts : 925
# Estoy calculando cosas !
# counts : 926
# Estoy calculando cosas !
# counts : 927
# Estoy calculando cosas !
# counts : 928
# Estoy calculando cosas !
# counts : 929
# Estoy calculando cosas !
# counts : 930
# Estoy calculando cosas !
# counts : 931
# Estoy calculando cosas !
# counts : 932
# Estoy calculando cosas !
# counts : 933
# Estoy calculando cosas !
# counts : 934
# Estoy calculando cosas !
# counts : 935
# Estoy calculando cosas !
# counts : 936
# Estoy calculando cosas !
# counts : 937
# Estoy calculando cosas !
# counts : 938
# Estoy calculando cosas !
# counts : 939
# Estoy calculando cosas !
# counts : 940
# Estoy calculando cosas !
# counts : 941
# Estoy calculando cosas !
# counts : 942
# Estoy calculando cosas !
# counts : 943
# Estoy calculando cosas !
# counts : 944
# Estoy calculando cosas !
# counts : 945
# Estoy calculando cosas !
# counts : 946
# Estoy calculando cosas !
# counts : 947
# Estoy calculando cosas !
# counts : 948
# Estoy calculando cosas !
# counts : 949
# Estoy calculando cosas !
# counts : 950
# Estoy calculando cosas !
# counts : 951
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 952
# Estoy calculando cosas !
# counts : 953
# Estoy calculando cosas !
# counts : 954
# Estoy calculando cosas !
# counts : 955
# Estoy calculando cosas !
# counts : 956
# Estoy calculando cosas !
# counts : 957
# Estoy calculando cosas !
# counts : 958
# Estoy calculando cosas !
# counts : 959
# Estoy calculando cosas !
# counts : 960
# Estoy calculando cosas !
# counts : 961
# Estoy calculando cosas !
# counts : 962
# Estoy calculando cosas !
# counts : 963
# Estoy calculando cosas !
# counts : 964
# Estoy calculando cosas !
# counts : 965
# Estoy calculando cosas !
# counts : 966
# Estoy calculando cosas !
# counts : 967
# Estoy calculando cosas !
# counts : 968
# Estoy calculando cosas !
# counts : 969
# Estoy calculando cosas !
# counts : 970
# Estoy calculando cosas !
# counts : 971
# Estoy calculando cosas !
# counts : 972
# Estoy calculando cosas !
# counts : 973
# Estoy calculando cosas !
# counts : 974
# Estoy calculando cosas !
# counts : 975
# Estoy calculando cosas !
# counts : 976
# Estoy calculando cosas !
# counts : 977
# Estoy calculando cosas !
# counts : 978
# Estoy calculando cosas !
# counts : 979
# Estoy calculando cosas !
# counts : 980
# Estoy calculando cosas !
# counts : 981
# Estoy calculando cosas !
# counts : 982
# Estoy calculando cosas !
# counts : 983
# Estoy calculando cosas !
# counts : 984
# Estoy calculando cosas !
# counts : 985
# Estoy calculando cosas !
# counts : 986
# Estoy calculando cosas !
# counts : 987
# Estoy calculando cosas !
# counts : 988
# Estoy calculando cosas !
# counts : 989
# Estoy calculando cosas !
# counts : 990
# Estoy calculando cosas !
# counts : 991
# Estoy calculando cosas !
# counts : 992
# Estoy calculando cosas !
# counts : 993
# Estoy calculando cosas !
# counts : 994
# Estoy calculando cosas !
# counts : 995
# Estoy calculando cosas !
# counts : 996
# Estoy calculando cosas !
# counts : 997
# Estoy calculando cosas !
# counts : 998
# Estoy calculando cosas !
# counts : 999
# Estoy calculando cosas !
# counts : 1000
# Estoy calculando cosas !
# counts : 1001
# Estoy calculando cosas !
# counts : 1002
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1003
# Estoy calculando cosas !
# counts : 1004
# Estoy calculando cosas !
# counts : 1005
# Estoy calculando cosas !
# counts : 1006
# Estoy calculando cosas !
# counts : 1007
# Estoy calculando cosas !
# counts : 1008
# Estoy calculando cosas !
# counts : 1009
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1010
# Estoy calculando cosas !
# counts : 1011
# Estoy calculando cosas !
# counts : 1012
# Estoy calculando cosas !
# counts : 1013
# Estoy calculando cosas !
# counts : 1014
# Estoy calculando cosas !
# counts : 1015
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1016
# Estoy calculando cosas !
# counts : 1017
# Estoy calculando cosas !
# counts : 1018
# Estoy calculando cosas !
# counts : 1019
# Estoy calculando cosas !
# counts : 1020
# Estoy calculando cosas !
# counts : 1021
# Estoy calculando cosas !
# counts : 1022
# Estoy calculando cosas !
# counts : 1023
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1024
# Estoy calculando cosas !
# counts : 1025
# Estoy calculando cosas !
# counts : 1026
# Estoy calculando cosas !
# counts : 1027
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1028
# Estoy calculando cosas !
# counts : 1029
# Estoy calculando cosas !
# counts : 1030
# Estoy calculando cosas !
# counts : 1031
# Estoy calculando cosas !
# counts : 1032
# Estoy calculando cosas !
# counts : 1033
# Estoy calculando cosas !
# counts : 1034
# Estoy calculando cosas !
# counts : 1035
# Estoy calculando cosas !
# counts : 1036
# Estoy calculando cosas !
# counts : 1037
# Estoy calculando cosas !
# counts : 1038
# Estoy calculando cosas !
# counts : 1039
# Estoy calculando cosas !
# counts : 1040
# Estoy calculando cosas !
# counts : 1041
# Estoy calculando cosas !
# counts : 1042
# Estoy calculando cosas !
# counts : 1043
# Estoy calculando cosas !
# counts : 1044
# Estoy calculando cosas !
# counts : 1045
# Estoy calculando cosas !
# counts : 1046
# Estoy calculando cosas !
# counts : 1047
# Estoy calculando cosas !
# counts : 1048
# Estoy calculando cosas !
# counts : 1049
# Estoy calculando cosas !
# counts : 1050
# Estoy calculando cosas !
# counts : 1051
# Estoy calculando cosas !
# counts : 1052
# Estoy calculando cosas !
# counts : 1053
# Estoy calculando cosas !
# counts : 1054
# Estoy calculando cosas !
# counts : 1055
# Estoy calculando cosas !
# counts : 1056
# Estoy calculando cosas !
# counts : 1057
# Estoy calculando cosas !
# counts : 1058
# Estoy calculando cosas !
# counts : 1059
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1060
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1061
# Estoy calculando cosas !
# counts : 1062
# Estoy calculando cosas !
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1063
# Estoy calculando cosas !
# counts : 1064
# Estoy calculando cosas !
# counts : 1065
# Estoy calculando cosas !
# counts : 1066
# Estoy calculando cosas !
# counts : 1067
# Estoy calculando cosas !
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1068
# Estoy calculando cosas !
# counts : 1069
# Estoy calculando cosas !
# counts : 1070
# Estoy calculando cosas !
# counts : 1071
# Estoy calculando cosas !
# counts : 1072
# Estoy calculando cosas !
# counts : 1073
# Estoy calculando cosas !
# counts : 1074
# Estoy calculando cosas !
# counts : 1075
# Estoy calculando cosas !
# counts : 1076
# Estoy calculando cosas !
# counts : 1077
# Estoy calculando cosas !
# counts : 1078
# Estoy calculando cosas !
# counts : 1079
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1080
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1081
# Estoy calculando cosas !
# counts : 1082
# Estoy calculando cosas !
# counts : 1083
# Estoy calculando cosas !
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1084
# Estoy calculando cosas !
# counts : 1085
# Estoy calculando cosas !
# counts : 1086
# Estoy calculando cosas !
# counts : 1087
# Estoy calculando cosas !
# counts : 1088
# Estoy calculando cosas !
# counts : 1089
# Estoy calculando cosas !
# counts : 1090
# Estoy calculando cosas !
# counts : 1091
# Estoy calculando cosas !
# counts : 1092
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1093
# Estoy calculando cosas !
# counts : 1094
# Estoy calculando cosas !
# counts : 1095
# Estoy calculando cosas !
# counts : 1096
# Estoy calculando cosas !
# counts : 1097
# Estoy calculando cosas !
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1098
# Estoy calculando cosas !
# counts : 1099
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1100
# Estoy calculando cosas !
# counts : 1101
# Estoy calculando cosas !
# counts : 1102
# Estoy calculando cosas !
# counts : 1103
# Estoy calculando cosas !
# counts : 1104
# Estoy calculando cosas !
# counts : 1105
# Estoy calculando cosas !
# counts : 1106
# Estoy calculando cosas !
# counts : 1107
# Estoy calculando cosas !
# counts : 1108
# Estoy calculando cosas !
# counts : 1109
# Estoy calculando cosas !
# counts : 1110
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1111
# Estoy calculando cosas !
# counts : 1112
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1113
# Estoy calculando cosas !
# counts : 1114
# Estoy calculando cosas !
# counts : 1115
# Estoy calculando cosas !
# counts : 1116
# Estoy calculando cosas !
# counts : 1117
# Estoy calculando cosas !
# counts : 1118
# Estoy calculando cosas !
# counts : 1119
# Estoy calculando cosas !
# counts : 1120
# Estoy calculando cosas !
# counts : 1121
# Estoy calculando cosas !
# counts : 1122
# Estoy calculando cosas !
# counts : 1123
# Estoy calculando cosas !
# counts : 1124
# Estoy calculando cosas !
# counts : 1125
# Estoy calculando cosas !
# counts : 1126
# Estoy calculando cosas !
# counts : 1127
# Estoy calculando cosas !
# counts : 1128
# Estoy calculando cosas !
# counts : 1129
# Estoy calculando cosas !
# counts : 1130
# Estoy calculando cosas !
# counts : 1131
# Estoy calculando cosas !
# counts : 1132
# Estoy calculando cosas !
# counts : 1133
# Estoy calculando cosas !
# counts : 1134
# Estoy calculando cosas !
# counts : 1135
# Estoy calculando cosas !
# counts : 1136
# Estoy calculando cosas !
# counts : 1137
# Estoy calculando cosas !
# counts : 1138
# Estoy calculando cosas !
# counts : 1139
# Estoy calculando cosas !
# counts : 1140
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1141
# Estoy calculando cosas !
# counts : 1142
# Estoy calculando cosas !
# counts : 1143
# Estoy calculando cosas !
# counts : 1144
# Estoy calculando cosas !
# counts : 1145
# Estoy calculando cosas !
# counts : 1146
# Estoy calculando cosas !
# counts : 1147
# Estoy calculando cosas !
# counts : 1148
# Estoy calculando cosas !
# counts : 1149
# Estoy calculando cosas !
# counts : 1150
# Estoy calculando cosas !
# counts : 1151
# Estoy calculando cosas !
# counts : 1152
# Estoy calculando cosas !
# counts : 1153
# Estoy calculando cosas !
# counts : 1154
# Estoy calculando cosas !
# counts : 1155
# Estoy calculando cosas !
# counts : 1156
# Estoy calculando cosas !
# counts : 1157
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1158
# Estoy calculando cosas !
# counts : 1159
# Estoy calculando cosas !
# counts : 1160
# Estoy calculando cosas !
# counts : 1161
# Estoy calculando cosas !
# counts : 1162
# Estoy calculando cosas !
# counts : 1163
# Estoy calculando cosas !
# counts : 1164
# Estoy calculando cosas !
# counts : 1165
# Estoy calculando cosas !
# counts : 1166
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1167
# Estoy calculando cosas !
# counts : 1168
# Estoy calculando cosas !
# counts : 1169
# Estoy calculando cosas !
# counts : 1170
# Estoy calculando cosas !
# counts : 1171
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1172
# Estoy calculando cosas !
# counts : 1173
# Estoy calculando cosas !
# counts : 1174
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1175
# Estoy calculando cosas !
# counts : 1176
# Estoy calculando cosas !
# counts : 1177
# Estoy calculando cosas !
# counts : 1178
# Estoy calculando cosas !
# counts : 1179
# Estoy calculando cosas !
# counts : 1180
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1181
# Estoy calculando cosas !
# counts : 1182
# Estoy calculando cosas !
# counts : 1183
# Estoy calculando cosas !
# counts : 1184
# Estoy calculando cosas !
# counts : 1185
# Estoy calculando cosas !
# counts : 1186
# Estoy calculando cosas !
# counts : 1187
# Estoy calculando cosas !
# counts : 1188
# Estoy calculando cosas !
# counts : 1189
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1190
# Estoy calculando cosas !
# counts : 1191
# Estoy calculando cosas !
# counts : 1192
# Estoy calculando cosas !
# counts : 1193
# Estoy calculando cosas !
# counts : 1194
# Estoy calculando cosas !
# counts : 1195
# Estoy calculando cosas !
# counts : 1196
# Estoy calculando cosas !
# counts : 1197
# Estoy calculando cosas !
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1198
# Estoy calculando cosas !
# counts : 1199
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1200
# Estoy calculando cosas !
# counts : 1201
# Estoy calculando cosas !
# counts : 1202
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1203
# Estoy calculando cosas !
# counts : 1204
# Estoy calculando cosas !
# counts : 1205
# Estoy calculando cosas !
# counts : 1206
# Estoy calculando cosas !
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1207
# Estoy calculando cosas !
# counts : 1208
# Estoy calculando cosas !
# counts : 1209
# Estoy calculando cosas !
# counts : 1210
# Estoy calculando cosas !
# counts : 1211
# Estoy calculando cosas !
# counts : 1212
# Estoy calculando cosas !
# counts : 1213
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1214
# Estoy calculando cosas !
# counts : 1215
# Estoy calculando cosas !
# counts : 1216
# Estoy calculando cosas !
# counts : 1217
# Estoy calculando cosas !
# counts : 1218
# Estoy calculando cosas !
# counts : 1219
# Estoy calculando cosas !
# counts : 1220
# Estoy calculando cosas !
# counts : 1221
# Estoy calculando cosas !
# counts : 1222
# Estoy calculando cosas !
# counts : 1223
# Estoy calculando cosas !
# counts : 1224
# Estoy calculando cosas !
# counts : 1225
# Estoy calculando cosas !
# counts : 1226
# Estoy calculando cosas !
# counts : 1227
# Estoy calculando cosas !
# counts : 1228
# Estoy calculando cosas !
# counts : 1229
# Estoy calculando cosas !
# counts : 1230
# Estoy calculando cosas !
# counts : 1231
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1232
# Estoy calculando cosas !
# counts : 1233
# Estoy calculando cosas !
# counts : 1234
# Estoy calculando cosas !
# counts : 1235
# Estoy calculando cosas !
# counts : 1236
# Estoy calculando cosas !
# counts : 1237
# Estoy calculando cosas !
# counts : 1238
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1239
# Estoy calculando cosas !
# counts : 1240
# Estoy calculando cosas !
# counts : 1241
# Estoy calculando cosas !
# counts : 1242
# Estoy calculando cosas !
# counts : 1243
# Estoy calculando cosas !
# counts : 1244
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1245
# Estoy calculando cosas !
# counts : 1246
# Estoy calculando cosas !
# counts : 1247
# Estoy calculando cosas !
# counts : 1248
# Estoy calculando cosas !
# counts : 1249
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1250
# Estoy calculando cosas !
# counts : 1251
# Estoy calculando cosas !
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1252
# Estoy calculando cosas !
# counts : 1253
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1254
# Estoy calculando cosas !
# counts : 1255
# Estoy calculando cosas !
# counts : 1256
# Estoy calculando cosas !
# counts : 1257
# Estoy calculando cosas !
# counts : 1258
# Estoy calculando cosas !
# counts : 1259
# Estoy calculando cosas !
# counts : 1260
# Estoy calculando cosas !
# counts : 1261
# Estoy calculando cosas !
# counts : 1262
# Estoy calculando cosas !
# counts : 1263
# Estoy calculando cosas !
# counts : 1264
# Estoy calculando cosas !
# counts : 1265
# Estoy calculando cosas !
# counts : 1266
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1267
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1268
# Estoy calculando cosas !
# counts : 1269
# Estoy calculando cosas !
# counts : 1270
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1271
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1272
# Estoy calculando cosas !
# counts : 1273
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1274
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1275
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1276
# Estoy calculando cosas !
# counts : 1277
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1278
# Estoy calculando cosas !
# counts : 1279
# Estoy calculando cosas !
# counts : 1280
# Estoy calculando cosas !
# counts : 1281
# Estoy calculando cosas !
# counts : 1282
# Estoy calculando cosas !
# counts : 1283
# Estoy calculando cosas !
# counts : 1284
# Estoy calculando cosas !
# counts : 1285
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1286
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1287
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1288
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1289
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1290
# Estoy calculando cosas !
# counts : 1291
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1292
# Estoy calculando cosas !
# counts : 1293
# Estoy calculando cosas !
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1294
# Estoy calculando cosas !
# counts : 1295
# Estoy calculando cosas !
# counts : 1296
# Estoy calculando cosas !
# counts : 1297
# Estoy calculando cosas !
# counts : 1298
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1299
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1300
# Estoy calculando cosas !
# counts : 1301
# Estoy calculando cosas !
# counts : 1302
# Estoy calculando cosas !
# counts : 1303
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1304
# Estoy calculando cosas !
# counts : 1305
# Estoy calculando cosas !
# counts : 1306
# Estoy calculando cosas !
# counts : 1307
# Estoy calculando cosas !
# counts : 1308
# Estoy calculando cosas !
# counts : 1309
# Estoy calculando cosas !
# counts : 1310
# Estoy calculando cosas !
# counts : 1311
# Estoy calculando cosas !
# counts : 1312
# Estoy calculando cosas !
# counts : 1313
# Estoy calculando cosas !
# counts : 1314
# Estoy calculando cosas !
# counts : 1315
# Estoy calculando cosas !
# counts : 1316
# Estoy calculando cosas !
# counts : 1317
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1318
# Estoy calculando cosas !
# counts : 1319
# Estoy calculando cosas !
# counts : 1320
# Estoy calculando cosas !
# counts : 1321
# Estoy calculando cosas !
# counts : 1322
# Estoy calculando cosas !
# counts : 1323
# Estoy calculando cosas !
# counts : 1324
# Estoy calculando cosas !
# counts : 1325
# Estoy calculando cosas !
# counts : 1326
# Estoy calculando cosas !
# counts : 1327
# Estoy calculando cosas !
# counts : 1328
# Estoy calculando cosas !
# counts : 1329
# Estoy calculando cosas !
# counts : 1330
# Estoy calculando cosas !
# counts : 1331
# Estoy calculando cosas !
# counts : 1332
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1333
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1334
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1335
# Estoy calculando cosas !
# counts : 1336
# Estoy calculando cosas !
# counts : 1337
# Estoy calculando cosas !
# counts : 1338
# Estoy calculando cosas !
# counts : 1339
# Estoy calculando cosas !
# counts : 1340
# Estoy calculando cosas !
# counts : 1341
# Estoy calculando cosas !
# counts : 1342
# Estoy calculando cosas !
# counts : 1343
# Estoy calculando cosas !
# counts : 1344
# Estoy calculando cosas !
# counts : 1345
# Estoy calculando cosas !
# Estoy calculando cosas !
# counts : 1346
# Estoy calculando cosas !
# counts : 1347
# ...
# counts : 15519
# counts : 15520
# counts : 15521
# counts : 15522
# counts : 15523
# counts : 15524
# counts : 15525
# counts : 15526
# counts : 15527
# counts : 15528
# counts : 15529
# counts : 15530
# counts : 15531
# counts : 15532
# counts : 15533
# counts : 15534
# counts : 15535
# counts : 15536
# counts : 15537
# counts : 15538
# counts : 15539
# counts : 15540
# counts : 15541
# counts : 15542
# counts : 15543
# counts : 15544
# counts : 15545
# counts : 15546
# counts : 15547
# counts : 15548
# counts : 15549
# counts : 15550
# counts : 15551
# counts : 15552
# counts : 15553
# counts : 15554
# counts : 15555
# counts : 15556
# counts : 15557
# counts : 15558
# counts : 15559
# counts : 15560
# counts : 15561
# counts : 15562
# counts : 15563
# counts : 15564
# counts : 15565
# counts : 15566
# counts : 15567
# counts : 15568
# counts : 15569
# counts : 15570
# counts : 15571
# counts : 15572
# counts : 15573
# counts : 15574
# counts : 15575
# counts : 15576
# counts : 15577
# counts : 15578
# counts : 15579
# counts : 15580
# counts : 15581
# counts : 15582
# counts : 15583
# counts : 15584
# counts : 15585
# counts : 15586
# counts : 15587
# counts : 15588
# counts : 15589
# counts : 15590
# counts : 15591
# counts : 15592
# counts : 15593
# counts : 15594
# counts : 15595
# counts : 15596
# counts : 15597
# counts : 15598
# counts : 15599
# counts : 15600
# counts : 15601
# counts : 15602
# counts : 15603
# counts : 15604
# counts : 15605
# counts : 15606
# counts : 15607
# counts : 15608
# counts : 15609
# counts : 15610
# counts : 15611
# counts : 15612
# counts : 15613
# counts : 15614
# counts : 15615
# counts : 15616
# counts : 15617
# counts : 15618
# counts : 15619
# counts : 15620
# counts : 15621
# counts : 15622
# counts : 15623
# counts : 15624
# counts : 15625
# counts : 15626
# counts : 15627
# counts : 15628
# counts : 15629
# counts : 15630
# counts : 15631
# counts : 15632
# counts : 15633
# counts : 15634
# counts : 15635
# counts : 15636
# counts : 15637
# counts : 15638
# counts : 15639
# counts : 15640
# counts : 15641
# counts : 15642
# counts : 15643
# counts : 15644
# counts : 15645
# counts : 15646
# counts : 15647
# counts : 15648
# counts : 15649
# counts : 15650
# counts : 15651
# counts : 15652
# counts : 15653
# counts : 15654
# counts : 15655
# counts : 15656
# counts : 15657
# counts : 15658
# counts : 15659
# counts : 15660
# counts : 15661
# counts : 15662
# counts : 15663
# counts : 15664
# counts : 15665
# counts : 15666
# counts : 15667
# counts : 15668
# counts : 15669
# counts : 15670
# counts : 15671
# counts : 15672
# counts : 15673
# counts : 15674
# counts : 15675
# counts : 15676
# counts : 15677
# counts : 15678
# counts : 15679
# counts : 15680
# counts : 15681
# counts : 15682
# counts : 15683
# counts : 15684
# counts : 15685
# counts : 15686
# counts : 15687
# counts : 15688
# counts : 15689
# counts : 15690
# counts : 15691
# counts : 15692
# counts : 15693
# counts : 15694
# counts : 15695
# counts : 15696
# counts : 15697
# counts : 15698
# counts : 15699
# counts : 15700
# counts : 15701
# counts : 15702
# counts : 15703
# counts : 15704
# counts : 15705
# counts : 15706
# counts : 15707
# counts : 15708
# counts : 15709
# counts : 15710
# counts : 15711
# counts : 15712
# counts : 15713
# counts : 15714
# counts : 15715
# counts : 15716
# counts : 15717
# counts : 15718
# counts : 15719
# counts : 15720
# counts : 15721
# counts : 15722
# counts : 15723
# counts : 15724
# counts : 15725
# counts : 15726
# counts : 15727
# counts : 15728
# counts : 15729
# counts : 15730
# counts : 15731
# counts : 15732
# counts : 15733
# counts : 15734
# counts : 15735
# counts : 15736
# counts : 15737
# counts : 15738
# counts : 15739
# counts : 15740
# counts : 15741
# counts : 15742
# counts : 15743
# counts : 15744
# counts : 15745
# counts : 15746
# counts : 15747
# counts : 15748
# counts : 15749
# counts : 15750
# counts : 15751
# counts : 15752
# counts : 15753
# counts : 15754
# counts : 15755
# counts : 15756
# counts : 15757
# counts : 15758
# counts : 15759
# counts : 15760
# counts : 15761
# counts : 15762
# counts : 15763
# counts : 15764
# counts : 15765
# counts : 15766
# counts : 15767
# counts : 15768
# counts : 15769
# counts : 15770
# counts : 15771
# counts : 15772
# counts : 15773
# counts : 15774
# counts : 15775
# counts : 15776
# counts : 15777
# counts : 15778
# counts : 15779
# counts : 15780
# counts : 15781
# counts : 15782
# counts : 15783
# counts : 15784
# counts : 15785
# counts : 15786
# counts : 15787
# counts : 15788
# counts : 15789
# counts : 15790
# counts : 15791
# counts : 15792
# counts : 15793
# counts : 15794
# counts : 15795
# counts : 15796
# counts : 15797
# counts : 15798
# counts : 15799
# counts : 15800
# counts : 15801
# counts : 15802
# counts : 15803
# counts : 15804
# counts : 15805
# counts : 15806
# counts : 15807
# counts : 15808
# counts : 15809
# counts : 15810
# counts : 15811
# counts : 15812
# counts : 15813
# counts : 15814
# counts : 15815
# counts : 15816
# counts : 15817
# counts : 15818
# counts : 15819
# counts : 15820
# counts : 15821
# counts : 15822
# counts : 15823
# counts : 15824
# counts : 15825
# counts : 15826
# counts : 15827
# counts : 15828
# counts : 15829
# counts : 15830
# counts : 15831
# counts : 15832
# counts : 15833
# counts : 15834
# counts : 15835
# counts : 15836
# counts : 15837
# counts : 15838
# counts : 15839
# counts : 15840
# counts : 15841
# counts : 15842
# counts : 15843
# counts : 15844
# counts : 15845
# counts : 15846
# counts : 15847
# counts : 15848
# counts : 15849
# counts : 15850
# counts : 15851
# counts : 15852
# counts : 15853
# counts : 15854
# counts : 15855
# counts : 15856
# counts : 15857
# counts : 15858
# counts : 15859
# counts : 15860
# counts : 15861
# counts : 15862
# counts : 15863
# counts : 15864
# counts : 15865
# counts : 15866
# counts : 15867
# counts : 15868
# counts : 15869
# counts : 15870
# counts : 15871
# counts : 15872
# counts : 15873
# counts : 15874
# counts : 15875
# counts : 15876
# counts : 15877
# counts : 15878
# counts : 15879
# counts : 15880
# counts : 15881
# counts : 15882
# counts : 15883
# counts : 15884
# counts : 15885
# counts : 15886
# counts : 15887
# counts : 15888
# counts : 15889
# counts : 15890
# counts : 15891
# counts : 15892
# counts : 15893
# counts : 15894
# counts : 15895
# counts : 15896
# counts : 15897
# counts : 15898
# counts : 15899
# counts : 15900
# counts : 15901
# counts : 15902
# counts : 15903
# counts : 15904
# counts : 15905
# counts : 15906
# counts : 15907
# counts : 15908
# counts : 15909
# counts : 15910
# counts : 15911
# counts : 15912
# counts : 15913
# counts : 15914
# counts : 15915
# counts : 15916
# counts : 15917
# counts : 15918
# counts : 15919
# counts : 15920
# counts : 15921
# counts : 15922
# counts : 15923
# counts : 15924
# counts : 15925
# counts : 15926
# counts : 15927
# counts : 15928
# counts : 15929
# counts : 15930
# counts : 15931
# counts : 15932
# counts : 15933
# counts : 15934
# counts : 15935
# counts : 15936
# counts : 15937
# counts : 15938
# counts : 15939
# counts : 15940
# counts : 15941
# counts : 15942
# counts : 15943
# counts : 15944
# counts : 15945
# counts : 15946
# counts : 15947
# counts : 15948
# counts : 15949
# counts : 15950
# counts : 15951
# counts : 15952
# counts : 15953
# counts : 15954
# counts : 15955
# counts : 15956
# counts : 15957
# counts : 15958
# counts : 15959
# counts : 15960
# counts : 15961
# counts : 15962
# counts : 15963
# counts : 15964
# counts : 15965
# counts : 15966
# counts : 15967
# counts : 15968
# counts : 15969
# counts : 15970
# counts : 15971
# counts : 15972
# counts : 15973
# counts : 15974
# counts : 15975
# counts : 15976
# counts : 15977
# counts : 15978
# counts : 15979
# counts : 15980
# counts : 15981
# counts : 15982
# counts : 15983
# counts : 15984
# counts : 15985
# counts : 15986
# counts : 15987
# counts : 15988
# counts : 15989
# counts : 15990
# counts : 15991
# counts : 15992
# counts : 15993
# counts : 15994
# counts : 15995
# counts : 15996
# counts : 15997
# counts : 15998
# counts : 15999
# counts : 16000
# counts : 16001
# counts : 16002
# counts : 16003
# counts : 16004
# counts : 16005
# counts : 16006
# counts : 16007
# counts : 16008
# counts : 16009
# counts : 16010
# counts : 16011
# counts : 16012
# counts : 16013
# counts : 16014
# counts : 16015
# counts : 16016
# counts : 16017
# counts : 16018
# counts : 16019
# counts : 16020
# counts : 16021
# counts : 16022
# counts : 16023
# counts : 16024
# counts : 16025
# counts : 16026
# counts : 16027
# counts : 16028
# counts : 16029
# counts : 16030
# counts : 16031
# counts : 16032
# counts : 16033
# counts : 16034
# counts : 16035
# counts : 16036
# counts : 16037
# counts : 16038
# counts : 16039
# counts : 16040
# counts : 16041
# counts : 16042
# counts : 16043
# counts : 16044
# counts : 16045
# counts : 16046
# counts : 16047
# counts : 16048
# counts : 16049
# counts : 16050
# counts : 16051
# counts : 16052
# counts : 16053
# counts : 16054
# counts : 16055
# counts : 16056
# counts : 16057
# counts : 16058
# counts : 16059
# counts : 16060
# counts : 16061
# counts : 16062
# counts : 16063
# counts : 16064
# counts : 16065
# counts : 16066
# counts : 16067
# counts : 16068
# counts : 16069
# counts : 16070
# counts : 16071
# counts : 16072
# counts : 16073
# counts : 16074
# counts : 16075
# counts : 16076
# counts : 16077
# counts : 16078
# counts : 16079
# counts : 16080
# counts : 16081
# counts : 16082
# counts : 16083
# counts : 16084
# counts : 16085
# counts : 16086
# counts : 16087
# counts : 16088
# counts : 16089
# counts : 16090
# counts : 16091
# counts : 16092
# counts : 16093
# counts : 16094
# counts : 16095
# counts : 16096
# counts : 16097
# counts : 16098
# counts : 16099
# counts : 16100
# counts : 16101
# counts : 16102
# counts : 16103
# counts : 16104
# counts : 16105
# counts : 16106
# counts : 16107
# counts : 16108
# counts : 16109
# counts : 16110
# counts : 16111
# counts : 16112
# counts : 16113
# counts : 16114
# counts : 16115
# counts : 16116
# counts : 16117
# counts : 16118
# counts : 16119
# counts : 16120
# counts : 16121
# counts : 16122
# counts : 16123
# counts : 16124
# counts : 16125
# counts : 16126
# counts : 16127
# counts : 16128
# counts : 16129
# counts : 16130
# counts : 16131
# counts : 16132
# counts : 16133
# counts : 16134
# counts : 16135
# counts : 16136
# counts : 16137
# counts : 16138
# counts : 16139
# counts : 16140
# counts : 16141
# counts : 16142
# counts : 16143
# counts : 16144
# counts : 16145
# counts : 16146
# counts : 16147
# counts : 16148
# counts : 16149
# counts : 16150
# counts : 16151
# counts : 16152
# counts : 16153
# counts : 16154
# counts : 16155
# counts : 16156
# counts : 16157
# counts : 16158
# counts : 16159
# counts : 16160
# counts : 16161
# counts : 16162
# counts : 16163
# counts : 16164
# counts : 16165
# counts : 16166
# counts : 16167
# counts : 16168
# counts : 16169
# counts : 16170
# counts : 16171
# counts : 16172
# counts : 16173
# counts : 16174
# counts : 16175
# counts : 16176
# counts : 16177
# counts : 16178
# counts : 16179
# counts : 16180
# counts : 16181
# counts : 16182
# counts : 16183
# counts : 16184
# counts : 16185
# counts : 16186
# counts : 16187
# counts : 16188
# counts : 16189
# counts : 16190
# counts : 16191
# counts : 16192
# counts : 16193
# counts : 16194
# counts : 16195
# counts : 16196
# counts : 16197
# counts : 16198
# counts : 16199
# counts : 16200
# counts : 16201
# counts : 16202
# counts : 16203
# counts : 16204
# counts : 16205
# counts : 16206
# counts : 16207
# counts : 16208
# counts : 16209
# counts : 16210
# counts : 16211
# counts : 16212
# counts : 16213
# counts : 16214
# counts : 16215
# counts : 16216
# counts : 16217
# counts : 16218
# counts : 16219
# counts : 16220
# counts : 16221
# counts : 16222
# counts : 16223
# counts : 16224
# counts : 16225
# counts : 16226
# counts : 16227
# counts : 16228
# counts : 16229
# counts : 16230
# counts : 16231
# counts : 16232
# counts : 16233
# counts : 16234
# counts : 16235
# counts : 16236
# counts : 16237
# counts : 16238
# counts : 16239
# counts : 16240
# counts : 16241
# counts : 16242
# counts : 16243
# counts : 16244
# counts : 16245
# counts : 16246
# counts : 16247
# counts : 16248
# counts : 16249
# counts : 16250
# counts : 16251
# counts : 16252
# counts : 16253
# counts : 16254
# counts : 16255
# counts : 16256
# counts : 16257
# counts : 16258
# counts : 16259
# counts : 16260
# counts : 16261
# counts : 16262
# counts : 16263
# counts : 16264
# counts : 16265
# counts : 16266
# counts : 16267
# counts : 16268
# counts : 16269
# counts : 16270
# counts : 16271
# counts : 16272
# counts : 16273
# counts : 16274
# counts : 16275
# counts : 16276
# counts : 16277
# counts : 16278
# counts : 16279
# counts : 16280
# counts : 16281
# counts : 16282
# counts : 16283
# counts : 16284
# counts : 16285
# counts : 16286
# counts : 16287
# counts : 16288
# counts : 16289
# counts : 16290
# counts : 16291
# counts : 16292
# counts : 16293
# counts : 16294
# counts : 16295
# counts : 16296
# counts : 16297
# counts : 16298
# counts : 16299
# counts : 16300
# counts : 16301
# counts : 16302
# counts : 16303
# counts : 16304
# counts : 16305
# counts : 16306
# counts : 16307
# counts : 16308
# counts : 16309
# counts : 16310
# counts : 16311
# counts : 16312
# counts : 16313
# counts : 16314
# counts : 16315
# counts : 16316
# counts : 16317
# counts : 16318
# counts : 16319
# counts : 16320
# counts : 16321
# counts : 16322
# counts : 16323
# counts : 16324
# counts : 16325
# counts : 16326
# counts : 16327
# counts : 16328
# counts : 16329
# counts : 16330
# counts : 16331
# counts : 16332
# counts : 16333
# counts : 16334
# counts : 16335
# counts : 16336
# counts : 16337
# counts : 16338
# counts : 16339
# counts : 16340
# counts : 16341
# counts : 16342
# counts : 16343
# counts : 16344
# counts : 16345
# counts : 16346
# counts : 16347
# counts : 16348
# counts : 16349
# counts : 16350
# counts : 16351
# counts : 16352
# counts : 16353
# counts : 16354
# counts : 16355
# counts : 16356
# counts : 16357
# counts : 16358
# counts : 16359
# counts : 16360
# counts : 16361
# counts : 16362
# counts : 16363
# counts : 16364
# counts : 16365
# counts : 16366
# counts : 16367
# counts : 16368
# counts : 16369
# counts : 16370
# counts : 16371
# counts : 16372
# counts : 16373
# counts : 16374
# counts : 16375
# counts : 16376
# counts : 16377
# counts : 16378
# counts : 16379
# counts : 16380
# counts : 16381
# counts : 16382
# counts : 16383
# counts : 16384
# counts : 16385
# counts : 16386
# counts : 16387
# counts : 16388
# counts : 16389
# counts : 16390
# counts : 16391
# counts : 16392
# counts : 16393
# counts : 16394
# counts : 16395
# counts : 16396
# counts : 16397
# counts : 16398
# counts : 16399
# counts : 16400
# counts : 16401
# counts : 16402
# counts : 16403
# counts : 16404
# counts : 16405
# counts : 16406
# counts : 16407
# counts : 16408
# counts : 16409
# counts : 16410
# counts : 16411
# counts : 16412
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-337aa534fd5d> in <module>
#      28 controlador = MiControlador()
#      29 LF = LineFollower(controlador)
# ---> 30 LF.run()
#      31 del(LF)
#      32
#
# ~/Dropbox/sync/notebooks/PUC/ICM2813/20202/PP2/ICM2813_20202_PP2_Alumnos/ICM2813/Server.py in run(self)
#     284
#     285
# --> 286             if self.checkEndFlag() == 1 and state == 16:
#     287                 self.stop()
#     288                 #print("Simulacion terminada ...")
#
# ~/Dropbox/sync/notebooks/PUC/ICM2813/20202/PP2/ICM2813_20202_PP2_Alumnos/ICM2813/Server.py in checkEndFlag(self)
#      84
#      85     def checkEndFlag(self):
# ---> 86         result = [self.client.simxReadProximitySensor(sensorHandle, self.client.simxServiceCall() ) for sensorHandle in self._endSensorHandles][0]
#      87         return result[1]
#      88
#
# ~/Dropbox/sync/notebooks/PUC/ICM2813/20202/PP2/ICM2813_20202_PP2_Alumnos/ICM2813/Server.py in <listcomp>(.0)
#      84
#      85     def checkEndFlag(self):
# ---> 86         result = [self.client.simxReadProximitySensor(sensorHandle, self.client.simxServiceCall() ) for sensorHandle in self._endSensorHandles][0]
#      87         return result[1]
#      88
#
# ~/Dropbox/sync/notebooks/PUC/ICM2813/20202/PP2/ICM2813_20202_PP2_Alumnos/ICM2813/b0RemoteApi.py in simxReadProximitySensor(self, handle, topic)
#     351     def simxReadProximitySensor(self,handle,topic):
#     352         reqArgs = [handle]
# --> 353         return self._handleFunction('ReadProximitySensor',reqArgs,topic)
#     354     def simxCheckProximitySensor(self,handle,entity,topic):
#     355         reqArgs = [handle,entity]
#
# ~/Dropbox/sync/notebooks/PUC/ICM2813/20202/PP2/ICM2813_20202_PP2_Alumnos/ICM2813/b0RemoteApi.py in _handleFunction(self, funcName, reqArgs, topic)
#      71         if topic==self._serviceCallTopic:
#      72             packedData=msgpack.packb([[funcName,self._clientId,topic,0],reqArgs])
# ---> 73             rep = msgpack.unpackb(self._serviceClient.call(packedData))
#      74             if len(rep)==1:
#      75                 rep.append(None)
#
# ~/Dropbox/sync/notebooks/PUC/ICM2813/20202/PP2/ICM2813_20202_PP2_Alumnos/ICM2813/b0.py in call(self, data)
#     231         outbuf = b0_service_client_call(self._cli, buf, sz, ct.byref(outsz))
#     232         outarr = ct.cast(outbuf, ct.POINTER(ct.c_ubyte * outsz.value))
# --> 233         rep_bytes = bytearray(outarr.contents)
#     234         return rep_bytes
#     235
#
# ValueError: NULL pointer access
